# %% [markdown]
# <h1>Text Lower</h1>

# %%
sentence = "Her cat's name is Luna"

# %%
lowered = sentence.lower()

# %%
lowered
# Out:
# "her cat's name is luna"

# %% [markdown]
# <h1>Remove Stop Words</h1>

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shubghos\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
en_stopwords = stopwords.words('english')

# %%
en_stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
sentence = "it was so far to go to the shop and he did not want her to walk"

# %%
sentence_no_stopwords = ' '.join([word for word in sentence.split() if word not in en_stopwords])
sentence_no_stopwords
# Out:
# 'far go shop want walk'

# %% [markdown]
# <h1>Regex</h1>

# %%
import re

# %%
# search option to find the string or pattern
result_search = re.search("pattern", r"string  is contain in pattern")
result_search
# Out:
# <re.Match object; span=(22, 29), match='pattern'>

# %%
# substitute function
string_new = re.sub("Sara", "Sarah", "Sara was able to help me find the items I neeed quickly")

# %%
string_new
# Out:
# 'Sarah was able to help me find the items I neeed quickly'

# %% [markdown]
# <h3>Find the customer reviews for Sarah</h3>

# %%
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i needed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted'
                   ]

# %%
sarah_customer_review = []
pattern = r"sara?"

# %%
sarah_reviews = [review for review in customer_reviews if re.search(pattern, review)]
sarah_reviews
# Out:
# ['sarah was able to help me find the items i needed quickly',
#  'great service from sara she found me what i wanted']

# %% [markdown]
# <h3>A Beginning Reviews</h3>

# %%
a_reviews = []
a_pattern = r"^a"

# %%
a_reviews_list = [review for review in customer_reviews if re.search(a_pattern, review)]
a_reviews_list
# Out:
# ['amazing work from sadeen!']

# %% [markdown]
#  <h3>End Y</h3>

# %%
y_end_reviews = []
y_end_pattern = r"y$"

# %%
y_end_reviews_list = [review for review in customer_reviews if re.search(y_end_pattern, review)]
y_end_reviews_list
# Out:
# ['sarah was able to help me find the items i needed quickly']

# %% [markdown]
# <h3>Or Operator</h3>

# %%
y_end_reviews = []
y_end_pattern = r"(need|want)ed"

# %%
y_end_reviews_list = [review for review in customer_reviews if re.search(y_end_pattern, review)]
y_end_reviews_list
# Out:
# ['sarah was able to help me find the items i needed quickly',
#  'great service from sara she found me what i wanted']

# %% [markdown]
# <h2>Removing Punctuation</h2>

# %%
without_punctuation = []
pattern_to_find = r"[^\w\s]"

# %%
without_punctuation = [re.sub(pattern_to_find, "", review) for review in customer_reviews]

# %%
without_punctuation
# Out:
# ['sam was a great help to me in the store',
#  'the cashier was very rude to me I think her name was eleanor',
#  'amazing work from sadeen',
#  'sarah was able to help me find the items i needed quickly',
#  'lucy is such a great addition to the team',
#  'great service from sara she found me what i wanted']

# %% [markdown]
# <h1>Tokenization</h1>

# %%
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\shubghos\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sentences = "Her car's name is Luna. Her dogs's name is Max"

# %%
sent_tokenize(sentences)
# Out:
# ["Her car's name is Luna.", "Her dogs's name is Max"]

# %%
word_tokenize("Her car's name is Luna.")
# Out:
# ['Her', 'car', "'s", 'name', 'is', 'Luna', '.']

# %%
word_tokenize(sentences)
# Out:
# ['Her',
#  'car',
#  "'s",
#  'name',
#  'is',
#  'Luna',
#  '.',
#  'Her',
#  'dogs',
#  "'s",
#  'name',
#  'is',
#  'Max']

# %% [markdown]
# <h2>Stemming</h2>

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
connect_token = ['connecting', 'connected', 'connectivity', 'connect', 'connects']

# %%
for t in connect_token:
    print(t , ":", ps.stem(t))
# Out:
# connecting : connect
# connected : connect
# connectivity : connect
# connect : connect
# connects : connect

# %%
learn_tokens = ['learned', 'learning', 'learn', 'learns', 'learner', 'learners']

# %%
for t in learn_tokens:
    print(t , ":", ps.stem(t))
# Out:
# learned : learn
# learning : learn
# learn : learn
# learns : learn
# learner : learner
# learners : learner

# %%
likes_tokens = ['likes', 'better', 'worse']

# %%
for t in likes_tokens:
    print(t , ":", ps.stem(t))
# Out:
# likes : like
# better : better
# worse : wors

# %% [markdown]
# <h2>Lemmatization</h2>

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shubghos\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
lemmatizer = WordNetLemmatizer()

# %%
for t in connect_token:
    print(t , ":", lemmatizer.lemmatize(t))
# Out:
# connecting : connecting
# connected : connected
# connectivity : connectivity
# connect : connect
# connects : connects

# %%
for t in learn_tokens:
    print(t , ":", lemmatizer.lemmatize(t))
# Out:
# learned : learned
# learning : learning
# learn : learn
# learns : learns
# learner : learner
# learners : learner

# %%
for t in likes_tokens:
    print(t , ":", lemmatizer.lemmatize(t))
# Out:
# likes : like
# better : better
# worse : worse

# %% [markdown]
#  <h1>N Grams</h1>

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
tokens = ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
tokens
# Out:
# ['the',
#  'rise',
#  'of',
#  'artificial',
#  'intelligence',
#  'has',
#  'led',
#  'to',
#  'significant',
#  'advancements',
#  'in',
#  'natural',
#  'language',
#  'processing',
#  'computer',
#  'vision',
#  'and',
#  'other',
#  'fields',
#  'machine',
#  'learning',
#  'algorithms',
#  'are',
#  'becoming',
#  'more',
#  'sophisticated',
#  'enabling',
#  'computers',
#  'to',
#  'perform',
#  'complex',
#  'tasks',
#  'that',
#  'were',
#  'once',
#  'thought',
#  'to',
#  'be',
#  'the',
#  'exclusive',
#  'domain',
#  'of',
#  'humans',
#  'with',
#  'the',
#  'advent',
#  'of',
#  'deep',
#  'learning',
#  'neural',
#  'networks',
#  'have',
#  'become',
#  'even',
#  'more',
#  'powerful',
#  'capable',
#  'of',
#  'processing',
#  'vast',
#  'amounts',
#  'of',
#  'data',
#  'and',
#  'learning',
#  'from',
#  'it',
#  'in',
#  'ways',
#  'that',
#  'were',
#  'not',
#  'possible',
#  'before',
#  'as',
#  'a',
#  'result',
#  'ai',
#  'is',
#  'increasingly',
# ...

# %%
unigrams = pd.Series(nltk.ngrams(tokens, 1)).value_counts()
unigrams[:10]
# Out:
# (to,)          7
# (of,)          6
# (the,)         4
# (in,)          4
# (learning,)    3
# (and,)         3
# (from,)        2
# (more,)        2
# (is,)          2
# (that,)        2
# Name: count, dtype: int64

# %%
unigrams[:10].sort_values().plot.barh(color="lightsalmon", width=9, figsize=(12,8))
plt.title("10 most frequently recurring words")
# Out:
# Text(0.5, 1.0, '10 most frequently recurring words')

# %%
bigrams = pd.Series(nltk.ngrams(tokens, 1)).value_counts()
bigrams[:10].sort_values().plot.barh(color="lightsalmon", width=9, figsize=(12,8))
plt.title("10 most frequently recurring words")
# Out:
# Text(0.5, 1.0, '10 most frequently recurring words')
